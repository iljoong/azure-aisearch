# %% [markdown]
# ## 3. Keyword/Text (FAQ) search with Korean Analyzer
#
# ### Analyzer
#
# - https://learn.microsoft.com/en-us/azure/search/search-analyzers
# - https://learn.microsoft.com/en-us/azure/search/index-add-language-analyzers

# %%
from dotenv import load_dotenv
load_dotenv("../.env")
# Out:
# True

# %%
from azure.core.credentials import AzureKeyCredential  
from azure.search.documents import SearchClient  
from azure.search.documents.indexes import SearchIndexClient  
from azure.search.documents.indexes.models import (  
    SearchIndex,  
    SearchField,  
    SearchFieldDataType,  
    SimpleField,  
    SearchableField,  
    SearchIndex,  
)

# %%
import os
service_endpoint = os.getenv("AZSCH_ENDPOINT")  
credential = AzureKeyCredential(os.environ["AZSCH_KEY"])

print(service_endpoint)
# Out:
# https://iksch.search.windows.net

# %%
# Create a search index
def create_search_index(index_name):
    index_client = SearchIndexClient(
        endpoint=service_endpoint, credential=credential)
    fields = [
        SimpleField(name="id", type=SearchFieldDataType.String, key=True),
        SearchableField(name="title", type=SearchFieldDataType.String,
                        searchable=True, retrievable=True,
                        analyzer_name="ko.microsoft"),
        SearchableField(name="body", type=SearchFieldDataType.String,
                        searchable=True, retrievable=True,
                        analyzer_name="ko.microsoft"),
        SearchableField(name="category", type=SearchFieldDataType.String,
                        searchable=False, retrievable=True,
                        facetable=True, filterable=True),
        SearchableField(name="type", type=SearchFieldDataType.String,
                        searchable=False, retrievable=True,
                        facetable=True, filterable=True),
        SearchableField(name="docid", type=SearchFieldDataType.String)
    ]

    # Create the search index
    index = SearchIndex(name=index_name, fields=fields)
    result = index_client.create_or_update_index(index)
    print(f' {result.name} created')

# %%
index_name = "ncfaqs-kor-index"
create_search_index(index_name)
# Out:
#  ncfaqs-kor-index created

# %%
search_client = SearchClient(endpoint=service_endpoint, index_name=index_name, credential=credential)

# %%
import pandas as pd
from tqdm import tqdm

# %%
df = pd.read_json("./sample_faqs.json")
df.head()
# Out:
#        id category                                   title  \
# 0  469829       계정                        계정 인증을 해제하고 싶어요.
# 1  412428       게임  밤까마귀 장비를 강화했는데 이벤트 및 업적 카운트에 반영되지 않아요.
# 2  398796   결제(PC)   웹 상점 - 결제 취소는 되었지만, 결제 금액이 환불되지 않았어요.
# 3  398795   결제(PC)                웹 상점 - 결제 수단 별 한도가 궁금해요.
# 4  398794   결제(PC)        웹 상점 - 상품을 구매했지만 보관함에 들어오지 않았어요.
#
#                                                 body
# 0  계정 인증 해제는 아래의 방법을 참고해 주시길 바랍니다.\n■ 계정 인증 해제 방법...
# 1  강화를 시도해도 파괴되지 않는 '보호의 밤까마귀 강화 주문서'로 강화했을 경우, 이...
# 2  결제 수단인 카드사 혹은 결제사의 정책에 따라 최종 결제 환불까지 영업일 기준 1~...
# 3  결제 수단 별 한도는 각 카드사 및 결제사의 정책에 따라 변동될 수 있습니다.\n▶...
# 4  웹 상점에서 상품을 구매하면, 공식 사이트 내 대표 캐릭터로 설정된 캐릭터에게 지급...

# %%
count = 0
batch_size = 40
for i in tqdm(range(0, len(df), batch_size)):
    # set end position of batch
    i_end = min(i+batch_size, len(df))
    
    documents = df[i:i_end].apply(
        lambda row: {'id': str(row.name), 
                     'title': row['title'], 
                     'body': row['body'],
                     'category': row['category'],
                     'type': "faq",
                     "docid": str(row["id"])
                    }, axis=1).to_list()
    
    result = search_client.upload_documents(documents)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.66it/s]

# %%
from azure.search.documents.models import (
    QueryType,
    SearchMode
)

import json

def azsch_text_query(query, type=QueryType.Simple, mode=SearchMode.Any):

    results = search_client.search(  
        search_text=query,
        query_type=type,
        search_mode=mode,
        search_fields=["body", "title"],
        select=["docid", "body", "title", "category", "type"],
        query_language="ko-kr",
        top=10 # for limiting text search
    ) 
    
    print("Search Results:")
    for i, result in enumerate(results, 1): 
        print(f"{i}) {result['@search.score']:.10f}: {result['docid']}, {result['title']}, {result['category']}")

# %% [markdown]
# ## Demo
#
# - basic keyword search
# - filter
# - paging
# - faceting

# %% [markdown]
# ### basic search

# %%
results = azsch_text_query('해외 접속')
# Out:
# Search Results:
# 1) 4.3750230000: 8, 나이트크로우를 해외에서 플레이할 수 있나요?, 설치/실행(MO)
# 2) 4.3445706000: 118, 게임을 탈퇴하고 싶어요., 계정
# 3) 4.1424384000: 63, 결제 내역(영수증)은 어디서 확인하나요?, 결제(MO)
# 4) 3.1623788000: 24, 공식 커뮤니티의 대표 캐릭터를 변경하고 싶습니다., 커뮤니티
# 5) 3.0660737000: 141, 스토어에서 업데이트하라고 하지만 스토어에서는 업데이트되지 않아요., 설치/실행(MO)
# 6) 2.4545364000: 20, 상품 결제 중 오류가 발생했어요., 결제(MO)
# 7) 2.0736270000: 14, 네트워크 오류로 이용 중 접속이 끊기는 현상이 발생합니다., 시스템(MO)
# 8) 1.9787881000: 95, 이용 중인 계정이 제재되었어요., 계정
# 9) 1.9602762000: 142, 나이트크로우 이용 중 강제 종료, 끊김, 지연 현상으로 이용이 어렵습니다., 설치/실행(MO)
# 10) 1.8250712000: 59, 결제 내역(영수증)은 어디서 확인하나요?, 결제(PC)

# %%
results = azsch_text_query('해외 플레이')
# Out:
# Search Results:
# 1) 8.0072900000: 8, 나이트크로우를 해외에서 플레이할 수 있나요?, 설치/실행(MO)
# 2) 3.5803380000: 63, 결제 내역(영수증)은 어디서 확인하나요?, 결제(MO)
# 3) 3.5048090000: 22, PC버전에서 결제를 진행할 수는 없나요?, 결제(PC)
# 4) 3.2277384000: 131, DirectX 11 버전과 12버전이 무슨 차이가 있나요?, 설치/실행(PC)
# 5) 3.0171359000: 125, PC 권장 사양을 알고 싶어요., 설치/실행(PC)
# 6) 2.4545364000: 20, 상품 결제 중 오류가 발생했어요., 결제(MO)
# 7) 2.2651446000: 137, 나이트크로우를 이용하기 위한 권장 사양을 알고 싶어요., 설치/실행(MO)
# 8) 2.1015399000: 13, 전체화면에서 창모드로 변경하고 싶어요., 시스템(PC)
# 9) 2.0327604000: 140, 나이트크로우에 접속할 수 없어요., 설치/실행(MO)
# 10) 1.7512813000: 59, 결제 내역(영수증)은 어디서 확인하나요?, 결제(PC)

# %% [markdown]
# ### Hightlight

# %%
def azsch_text_query_highlight(query):

    results = search_client.search(  
        search_text=query,
        query_type=QueryType.Simple,
        search_mode=SearchMode.Any,
        search_fields=["body", "title"],
        select=["docid", "body", "title", "category", "type"],
        highlight_fields="body",
        query_language="ko-kr",
        top=5 # for limiting text search
    ) 
    
    print("Search Results:")
    for i, result in enumerate(results, 1):  
        if (result["@search.highlights"]):
            print(f"{result['docid']}: {result['@search.score']:.10f}: {result['title']}")
            for highlight in result['@search.highlights']['body']:
                print(f"    {highlight}")
        else:
            print(f"{result['docid']}: {result['@search.score']:.10f}: {result['title']} - {result['body']}")

# %%
azsch_text_query_highlight("해외 접속")
# Out:
# Search Results:
# 8: 4.3750230000: 나이트크로우를 해외에서 플레이할 수 있나요?
#     그러므로 <em>해외에서</em> 다운로드 및 플레이는 어려울 수 있는 점 양해 부탁드립니다.
# 118: 4.3445706000: 게임을 탈퇴하고 싶어요.
#     나이트크로우의 계정 탈퇴를 위해서는 먼저 게임 내 <em>접속이</em> 이루어져야 합니다.<em>접속</em> 후 [메뉴] &gt; [설정] &gt; [계정] 순으로 이동한 뒤, 최하단에 위치한 [게임탈퇴] 버튼을 눌러 진행하실 수 있습니다.
# ※ 게임 탈퇴는 72시간의 대기 시간이 적용됩니다. 72시간이 지나지 않은 상태에서 탈퇴 신청한 계정으로 재<em>접속</em>할 시에는 [게임 탈퇴 철회] 팝업창이 노출됩니다.※ 게임 탈퇴 대기 시간이 지난 후에는 게임 내 모든 정보가 삭제되며 복구가 불가능하오니 신중히 선택하시길 바랍니다.
# 63: 4.1424384000: 결제 내역(영수증)은 어디서 확인하나요?
#     구글 플레이 스토어에 연결된 구글 계정으로 Gmail에 <em>접속</em>합니다.2.
#     구글 페이먼트(https://pay.google.com) 사이트에 <em>접속</em>합니다.2.
# 24: 3.1623788000: 공식 커뮤니티의 대표 캐릭터를 변경하고 싶습니다.
#
# ■ 나이트 크로우 공식 커뮤니티 대표 캐릭터 변경 방법나이트 크로우 공식 커뮤니티 <em>접속</em> &gt; 캐릭터가 속해있는 연동 소셜 계정으로 로그인 &gt; 화면 우측 중단 직업 아이콘 클릭 &gt; 대표 캐릭터 변경 클릭 &gt; 대표 캐릭터로 설정할 캐릭터명 선택 &gt; 확인 버튼 클릭
# 141: 3.0660737000: 스토어에서 업데이트하라고 하지만 스토어에서는 업데이트되지 않아요.
#     나이트크로우의 게임 <em>접속이</em> 원활치 않다면 아래 내용을 확인해주시길 바랍니다.
# 1.
#     ＊다수의 사람들이 모여있는 장소 혹은 밀폐된 공간에서는 네트워크 <em>접속이</em> 원활하지 않습니다.

# %%
azsch_text_query_highlight("해외 플레이")
# Out:
# Search Results:
# 8: 8.0072900000: 나이트크로우를 해외에서 플레이할 수 있나요?
#     그러므로 <em>해외에서</em> 다운로드 및 <em>플레이는</em> 어려울 수 있는 점 양해 부탁드립니다.
# 63: 3.5803380000: 결제 내역(영수증)은 어디서 확인하나요?
#     구글 <em>플레이</em> 스토어에 연결된 구글 계정으로 Gmail에 접속합니다.2.
# 22: 3.5048090000: PC버전에서 결제를 진행할 수는 없나요?
#     나이트 크로우에서는 구글 <em>플레이를</em> 통한 PC버전에서의 결제를 지원하고 있습니다.
#     [PC 버전 결제 (구글<em>플레이</em>) 가이드 바로가기]
# 131: 3.2277384000: DirectX 11 버전과 12버전이 무슨 차이가 있나요?
#     .- DirectX 11 버전 : 기본으로 제공하는 버전- DirectX 12 버전 : CPU, GPU의 효율을 높여 더욱 뛰어난 그래픽 품질을 제공하는 버전
# DirectX 12 버전은 기본으로 제공하는 DirectX 11 버전보다 더욱 뛰어나고 안정적인 그래픽 품질로 게임을 <em>플레이</em>할 수 있습니다.
# 125: 3.0171359000: PC 권장 사양을 알고 싶어요.
#     .※ 나이트크로우는 32bit 운영 체제의 PC에서는 <em>플레이가</em> 불가하며, 64bit의 운영 체제에서만 이용이 가능합니다.

# %%
azsch_text_query_highlight("상품 구매 실패")
# Out:
# Search Results:
# 64: 12.3807720000: 구매한 상품은 어디에서 받을 수 있나요?
#     나이트 크로우 상점에서 <em>구매</em>한 <em>상품은</em> 상점 내 <em>상품</em> 보관함에서 확인하실 수 있습니다.
# ■ <em>상품</em> 수령 방법[메뉴] &gt; [상점] &gt; [<em>상품</em> 보관함]에서 <em>구매</em>하신 <em>상품을</em> 수령할 수 있습니다.
# 229992: 12.2555870000: 상품 구매에 실패하였습니다.(P:-477) 에러가 발생해요.
#     <em>상품</em> <em>구매에</em> <em>실패</em>하였습니다.
# 21: 11.5182990000: 구매한 상품은 어디에서 받을 수 있나요?
#     나이트 크로우 상점에서 <em>구매</em>한 <em>상품은</em> 상점 내 <em>상품</em> 보관함에서 확인하실 수 있습니다
#
# ■ <em>상품</em> 수령 방법[메뉴] &gt; [상점] &gt; [<em>상품</em> 보관함]에서 <em>구매</em>하신 <em>상품을</em> 수령할 수 있습니다.
# 398794: 9.8779660000: 웹 상점 - 상품을 구매했지만 보관함에 들어오지 않았어요.
#     웹 상점에서 <em>상품을</em> <em>구매</em>하면, 공식 사이트 내 대표 캐릭터로 설정된 캐릭터에게 지급됩니다.＊ 지급된 <em>상품은</em> [메뉴 &gt; 우편함 &gt; 시스템]에서 수령할 수 있습니다.
# 60: 9.4236555000: 상품을 환불하고 싶어요.
#     결제하신 <em>상품은</em> <em>구매일로부터</em> 7일 이내 상점 내 <em>상품</em> 보관함에서 수령하지 않은 <em>상품에</em> 한하여 청약 철회가 가능합니다.청약 철회를 위해서는 서버, 캐릭터명과 결제를 진행하신 스토어, <em>구매</em> 일시, 주문번호를 포함하여 문의 접수를 부탁드립니다.※ 결제한 <em>상품을</em> 이미 수령/사용했거나 결제 즉시 적용되는 <em>상품의</em> 경우, <em>상품의</em> <em>구매</em> 취소 및 환불이 제한됩니다.

# %%
azsch_text_query_highlight("마력 확률")
# Out:
# Search Results:
# 38233: 8.7895240000: 마력 주입 확률이 궁금해요.
#     <em>마력</em> 주입 <em>확률을</em> 안내해 드립니다.
#     <em>마력</em> 주입<em>마력</em> 주입 I구분능력치수치<em>확률</em>1번 능력치PVE 추가 피해315.00%PVE 추가 피해210.00%PVE 추가 피해110.00%생명력 물약 회복량1015.00%생명력 물약 회복량85.00%생명력 물약 회복량65.00%생명력 물약 회복량45.00%생명력 물약 회복량24.50%생명력 물약 회복량10.50%생명력 회복량515.00%생명력 회복량43.75%생명력 회복량33.75%생명력 회복량23.75%생명력 회복량13.75%2번 능력치PVE 명중215.00%PVE 명중120.00%최대 생명력10015.00%최대 생명력872.14%최대 생명력742.14%최대 생명력612.14%최대 생명력482.14%최대 생명력352.14%최대 생명력222.15%최대 생명력102.15%생명력 물약 회복률50015.00%생명력 물약 회복률4005.00%생명력 물약 회복률3005.00%생명력 물약 회복률2005.00%생명력 물약 회복률1005.00%3번 능력치PVE 치명타315.00%PVE 치명타210.00%PVE 치명타110.00%최대 정신력6015.00%최대 정신력532.14%최대 정신력462.14%최대 정신력392.14%최대 정신력322.14%최대 정신력252.14%최대 정신력182.15%최대 정신력102.15%최대 무게5,00015.00%최대 무게4,0005.00%최대 무게3,0005.00%최대 무게2,0005.00%최대 무게1,0005.00%추가 능력치방어2100.00%<em>마력</em> 주입 II구분능력치수치<em>확률</em>1번 능력치기술 피해45.00%기술 피해35.00%기술 피해25.00%기술 피해15.00%정신력 회복량710.00%정신력 회복량63.33%정신력 회복량53.33%정신력 회복량43.33%정신력 회복량33.33%정신력 회복량23.34%정신력 회복량13.34%최대 정신력7015.00%최대 정신력615.00%최대 정신력525.00%최대 정신력435.00%최대 정신력345.00%최대 정신력255.00%최대 정신력165.00%최대 정신력105.00%2번 능력치방어25.00%방어115.00%생명력
#     받는 치유량 증가율8001.80%받는 치유량 증가율7001.80%받는 치유량 증가율6001.80%받는 치유량 증가율5001.80%받는 치유량 증가율4001.80%받는 치유량 증가율3001.80%받는 치유량 증가율2001.70%받는 치유량 증가율1001.70%3번 능력치힘33.00%힘24.50%힘14.50%민첩33.00%민첩24.50%민첩14.50%지능33.00%지능24.50%지능14.50%체력23.50%체력117.50%정신23.50%정신117.50%인내23.50%인내118.50%추가 능력치극대화 <em>확률</em>3%100.00%<em>마력</em> 주입2 I구분능력치수치<em>확률</em>1번 능력치일반 공격 추가 피해55.00%일반 공격 추가 피해42.50%일반 공격 추가 피해32.50%일반 공격 추가 피해22.50%일반 공격 추가 피해12.50%기술 피해55.00%기술 피해42.50%기술 피해32.50%기술 피해22.50%기술 피해12.50%최대 생명력12010.00%최대 생명력1002.60%최대 생명력802.60%최대 생명력602.60%최대 생명력402.60%최대 생명력202.60%최대 정신력6010.00%최대 정신력502.60%최대 정신력402.60%최대 정신력302.60%최대 정신력202.60%최대 정신력102.60%최대 무게5010.00%최대 무게403.50%최대 무게303.50%최대 무게203.50%최대 무게103.50%2번 능력치이중 피해63.00%이중 피해52.40%이중 피해42.40%이중 피해32.40%이중 피해22.40%이중 피해12.40%근거리 이중 피해46.00%근거리 이중 피해34.70%근거리 이중 피해24.70%근거리 이중 피해14.60%원거리 이중 피해46.00%원거리 이중 피해34.70%원거리 이중 피해24.70%원거리 이중 피해14.60%마법 이중 피해46.00%마법 이중 피해34.70%마법 이중 피해24.70%마법 이중 피해14.60%이중 피해 저항48.00%이중 피해 저항35.70%이중 피해 저항25.70%이중 피해 저항15.60%3번 능력치명중41.50%명중32.90%
#     최대 정신력203.10%3번 능력치명중41.50%명중32.90%명중22.80%명중12.80%일반형 명중25.50%일반형 명중119.50%보스형 명중25.00%보스형 명중120.00%PVE 명중24.00%PVE 명중116.00%PVP 명중24.00%PVP 명중116.00%추가 능력치명중2100.00%<em>마력</em> 주입2 III구분능력치수치<em>확률</em>1번 능력치피해 감소710.00%피해 감소60.90%피해 감소50.90%피해 감소40.80%피해 감소30.80%피해 감소20.80%피해 감소10.80%PVE 피해 감소37.00%PVE 피해 감소26.50%PVE 피해 감소16.50%PVP 피해 감소37.00%PVP 피해 감소26.50%PVP 피해 감소16.50%기술 피해 감소37.00%기술 피해 감소26.50%기술 피해 감소16.50%범위 피해 감소39.00%범위 피해 감소28.00%범위 피해 감소18.00%2번 능력치명중43.00%명중32.40%명중22.30%명중12.30%근거리 명중26.00%근거리 명중114.00%원거리 명중26.00%원거리 명중114.00%마법 명중26.00%마법 명중114.00%생명력 물약 회복량58.00%생명력 물약 회복량45.50%생명력 물약 회복량35.50%생명력 물약 회복량25.50%생명력 물약 회복량15.50%3번 능력치방어41.50%방어32.90%방어22.80%방어12.80%PVE 방어26.00%PVE 방어119.00%PVP 방어26.00%PVP 방어119.00%기술 방어26.50%기술 방어133.50%추가 능력치극대화 저항 <em>확률</em>1.5%100.00%<em>마력</em> 주입2 IV구분능력치수치<em>확률</em>1번 능력치이중 피해610.00%이중 피해51.00%이중 피해41.00%이중 피해31.00%이중 피해21.00%이중 피해11.00%근거리 이중 피해44.50%근거리 이중 피해35.20%근거리 이중 피해25.20%근거리 이중 피해15.10%원거리 이중 피해44.50%원거리 이중 피해35.20%원거리 이중 피해25.20%원거리 이중 피해15.10%마법 이중 피해44.50%마법 이중
#     피해35.20%마법 이중 피해25.20%마법 이중 피해15.10%이중 피해 저항46.50%이중 피해 저항36.20%이중 피해 저항26.20%이중 피해 저항16.10%2번 능력치기본 피해73.00%기본 피해62.00%기본 피해52.00%기본 피해42.00%기본 피해32.00%기본 피해22.00%기본 피해12.00%근거리 피해34.00%근거리 피해28.00%근거리 피해18.00%원거리 피해34.00%원거리 피해28.00%원거리 피해18.00%마법 피해34.00%마법 피해28.00%마법 피해18.00%치명타 피해35.00%치명타 피해210.00%치명타 피해110.00%3번 능력치명중41.00%명중33.00%명중23.00%명중13.00%PVE 명중23.00%PVE 명중117.00%PVP 명중23.00%PVP 명중117.00%생명력 회복량74.00%생명력 회복량63.50%생명력 회복량53.50%생명력 회복량43.50%생명력 회복량33.50%생명력 회복량23.50%생명력 회복량13.50%정신력 회복량44.00%정신력 회복량37.00%정신력 회복량27.00%정신력 회복량17.00%추가 능력치극대화 <em>확률</em>1.5%100.00%<em>마력</em> 주입2 V구분능력치수치<em>확률</em>1번 능력치체력33.30%체력25.90%체력15.80%정신33.30%정신25.90%정신15.80%인내33.30%인내25.90%인내15.80%치명타 피해 감소1010.00%치명타 피해 감소91.70%치명타 피해 감소81.70%치명타 피해 감소71.70%치명타 피해 감소61.70%치명타 피해 감소51.70%치명타 피해 감소41.70%치명타 피해 감소31.60%치명타 피해 감소21.60%치명타 피해 감소11.60%범위 피해 감소1010.10%범위 피해 감소92.30%범위 피해 감소82.20%범위 피해 감소72.20%범위 피해 감소62.20%범위 피해 감소52.20%범위 피해 감소42.20%범위 피해 감소32.20%범위 피해 감소22.20%범위 피해 감소12.20%2번 능력치피해 감소73.00%피해 감소62.00%피해 감소52.00%
# 38234: 7.0082016000: 아이템 상자의 확률이 궁금해요.
#     아이템 상자 <em>확률을</em> 안내해 드립니다.
#     기타 <em>확률형</em> 아이템골드 상자이름수량<em>확률</em>골드30,00050.00%골드90,00034.00%골드150,00014.90%골드600,0001.00%골드1,000,0000.10%합계100.00%빛나는 무기 강화 주문서 상자이름수량<em>확률</em>광휘의 무기 강화 주문서(귀속)10.10%무기 강화 주문서(귀속)199.90%합계100.00%빛나는 방어구 강화 주문서 상자이름수량<em>확률</em>광휘의 방어구 강화 주문서(귀속)10.10%방어구 강화 주문서(귀속)199.90%합계100.00%빛나는 장신구 강화 주문서 상자이름수량<em>확률</em>광휘의 장신구 강화 주문서(귀속)10.10%장신구 강화 주문서(귀속)199.90%합계100.00%빛나는 아티팩트 강화 주문서 상자이름수량<em>확률</em>광휘의 아티팩트 강화 주문서(귀속)10.10%아티팩트 강화 주문서(귀속)199.90%합계100.00%찬란한 무기 강화 주문서 상자이름수량<em>확률</em>광휘의 무기 강화 주문서(귀속)10.75%무기 강화 주문서(귀속)199.25%합계100.00%찬란한 방어구 강화 주문서 상자이름수량<em>확률</em>광휘의 방어구 강화 주문서(귀속)10.75%방어구 강화 주문서(귀속)199.25%합계100.00%찬란한 장신구 강화 주문서 상자이름수량<em>확률</em>광휘의 장신구 강화 주문서(귀속)10.75%장신구 강화 주문서(귀속)199.25%합계100.00%8-9.
#     빛나는 무기 세공석 상자이름수량<em>확률</em>광휘의 무기 세공석(귀속)10.10%무기 세공석(귀속)199.90%합계100.00%빛나는 방어구 세공석 상자이름수량<em>확률</em>광휘의 방어구 세공석(귀속)10.10%방어구 세공석(귀속)199.90%합계100.00%빛나는 장신구 세공석 상자이름수량<em>확률</em>광휘의 장신구 세공석(귀속)10.10%장신구 세공석(귀속)199.90%합계100.00%빛나는 아티팩트 세공석 상자이름수량<em>확률</em>광휘의 아티팩트 세공석(귀속)10.10%아티팩트 세공석(귀속)199.90%합계100.00%5월 18일(목) 추가 <em>확률형</em> 상품길드 주화 꾸러미이름수량<em>확률</em>길드 주화10014.29%20016.00%30020.00%50025.00%1,00020.00%3,0003.00%7,0001.20%10,0000.50%150,0000.01%합계100.00%공헌 주화 꾸러미이름수량<em>확률</em>공헌 주화5014.29%10016.00%15020.00%25025.00%50020.00%1,5003.00%3,5001.20%5,0000.50%75,0000.01%합계100.00%5월 25일(목) 추가 <em>확률형</em> 상품장인의 밤까마귀 장비 상자 I이름수량<em>확률</em>+9 밤까마귀 발톱 부적 상자(귀속)10.20%+8 밤까마귀 발톱 부적 상자(귀속)10.40%+7 밤까마귀 발톱 부적 상자(귀속)10.80%+6 밤까마귀 발톱 부적 상자(귀속)15.60%+5 밤까마귀 발톱 부적 상자(귀속)18.00%+4 밤까마귀 발톱 부적 상자(귀속)120.00%+3 밤까마귀 발톱 부적 상자(귀속)165.00%합계100.00%장인의 밤까마귀 장비 상자 II이름수량<em>확률</em>+9 밤까마귀 깃털 브로치 상자(귀속)10.20%+8 밤까마귀 깃털 브로치 상자(귀속)10.40%+7 밤까마귀 깃털 브로치 상자(귀속)10.80%+6 밤까마귀 깃털 브로치 상자(귀속)15.60%+5 밤까마귀 깃털 브로치 상자(귀속)18.00%+4 밤까마귀 깃털 브로치 상자(귀속)120.00%+3 밤까마귀 깃털 브로치 상자(귀속)165.00%합계100.00% 클레멘스의 재료 상자이름수량<em>확률</em>모리온
#     (귀속)13.00%상급 전직의 증표(귀속)10.05%얼어붙은 눈물(귀속)10.02%상급 단련의 비전서(귀속)10.01%상급 도약의 비전서(귀속)10.01%상급 총명의 비전서(귀속)10.01%상급 번영의 비전서(귀속)10.01%지혜의 원천(귀속)10.01%창공의 조각(귀속)10.01%대장장이의 철주괴(귀속)11.60%세공사의 수정(귀속)11.60%무두장이의 가죽(귀속)11.60%무두장이의 모피(귀속)11.60%목수의 목재(귀속)11.60%고대 파피루스(귀속)12.50%단련의 비전서(귀속)10.75%도약의 비전서(귀속)10.75%총명의 비전서(귀속)10.75%번영의 비전서(귀속)10.75%성장의 원천(귀속)12.87%철주괴(귀속)14.00%수정 결정(귀속)14.00%부드러운 가죽(귀속)14.00%천연 모피(귀속)14.00%목재(귀속)14.00%초정밀 비행 부품(귀속)11.50%월장석(귀속)19.00%혼합 시약(귀속)19.00%철광석(귀속)17.20%수정 광물(귀속)17.20%거친 가죽(귀속)17.20%털뭉치(귀속)17.20%통나무(귀속)17.20%낡은 비행 부품(귀속)15.00%합계100.00%찬란한 장신구 강화 주문서 상자이름수량<em>확률</em>광휘의 장신구 강화 주문서(귀속)10.75%장신구 강화 주문서(귀속)199.25%합계100.00%찬란한 무기 세공석 상자이름수량<em>확률</em>광휘의 무기 세공석(귀속)10.75%무기 세공석(귀속)199.25%합계100.00%찬란한 방어구 세공석 상자이름수량<em>확률</em>광휘의 방어구 세공석(귀속)10.75%방어구 세공석(귀속)199.25%합계100.00%찬란한 장신구 세공석 상자이름수량<em>확률</em>광휘의 장신구 세공석(귀속)10.75%장신구 세공석(귀속)199.25%합계100.00%6월 15일(목) 추가 <em>확률형</em> 상품<em>마력</em> 룬 결정 II 랜덤 상자이름수량<em>확률</em><em>마력</em> 룬 결정 II(귀속)548.50%<em>마력</em> 룬 결정 II(귀속)730.00%<em>마력</em> 룬 결정 II(귀속)1015.00%<em>마력</em> 룬 결정 II(귀속)203.00%<em>마력</em> 룬 결정 II(귀속)302.00%<em>마력</em> 룬 결정 II(귀속)
#     401.00%<em>마력</em> 룬 결정 II(귀속)500.50%합계100.00%6월 29일(목) 추가 <em>확률형</em> 상품검은 날개 보급품이름수량<em>확률</em>돌격의 영약(귀속)209.00%필승의 영약(귀속)109.00%음식 바구니(귀속)59.00%파수의 영약(귀속)59.00%영약 선택 상자(귀속)39.00%월광 보호 부적(귀속)39.00%태양 전투 부적(귀속)39.00%무기 강화 주문서(귀속)26.15%방어구 강화 주문서(귀속)26.15%장신구 강화 주문서(귀속)26.15%무기 세공석(귀속)26.15%방어구 세공석(귀속)26.15%장신구 세공석(귀속)26.15%모리온(귀속)1000.10%합계100.00%8월 3일(목) 추가 <em>확률형</em> 상품100일 기념 클레멘스의 재료 상자이름수량<em>확률</em>얼어붙은 눈물(귀속)122.0%지혜의 원천(귀속)11.0%상급 단련의 비전서(귀속)10.5%상급 도약의 비전서(귀속)10.5%상급 총명의 비전서(귀속)10.5%상급 번영의 비전서(귀속)10.5%단련의 비전서(귀속)111.0%도약의 비전서(귀속)111.0%총명의 비전서(귀속)111.0%번영의 비전서(귀속)111.0%광휘의 무기 강화 주문서(귀속)11.0%광휘의 방어구 강화 주문서(귀속)11.0%광휘의 장신구 강화 주문서(귀속)11.0%초정밀 비행 부품(귀속)128.0%합계100.00%8월 10일(목) 추가 <em>확률형</em> 상품100일 기념 클레멘스의 재료 상자 II이름수량<em>확률</em>대장장이의 철주괴(귀속)52.5%무두장이의 가죽(귀속)52.5%무두장이의 모피(귀속)52.5%세공사의 수정(귀속)52.5%철주괴(귀속)255.0%부드러운 가죽(귀속)255.0%천연 모피(귀속)255.0%수정 결정(귀속)255.0%금속 파편(귀속)5025.0%골드 상자(귀속)120.0%사금 주머니(귀속)125.0%합계100.00%9월 21일(목) 추가 <em>확률형</em> 상품쓸만한 단결의 선물상자(귀속)이름수량<em>확률</em>골드 상자(귀속)124.04858301%무기 강화 주문서(귀속)19.35222672%방어구 강화 주문서(귀속)19.35222672%장신구 강화 주문서(귀속)19.35222672%
# 38204: 5.8078356000: 무기 외형 소환 확률이 궁금해요.
#     무기 외형 소환 <em>확률을</em> 안내해 드립니다.
#
#     희귀 무기 외형 소환 - 창이름등급소환 <em>확률</em>쇄도의 돌풍희귀17.00000000%쇄도의 안개희귀17.00000000%쇄도의 바람희귀17.00000000%쇄도의 증폭희귀15.33333333%쇄도의 폭풍희귀15.33333333%쇄도의 숨결희귀15.33333333%쇄도의 장막희귀1.00000000%쇄도의 비상희귀1.00000000%쇄도의 삭풍희귀1.00000000%합계100.00000000%1-18.
#     희귀 무기 외형 소환 - 쌍검이름등급소환 <em>확률</em>고통의 돌풍희귀17.00000000%고통의 안개희귀17.00000000%고통의 바람희귀17.00000000%고통의 증폭희귀15.33333333%고통의 폭풍희귀15.33333333%고통의 숨결희귀15.33333333%고통의 장막희귀1.00000000%고통의 비상희귀1.00000000%고통의 삭풍희귀1.00000000%합계100.00000000%1-20.
#     희귀 무기 외형 소환 - 활이름등급소환 <em>확률</em>간파의 돌풍희귀17.00000000%간파의 안개희귀17.00000000%간파의 바람희귀17.00000000%간파의 증폭희귀15.33333333%간파의 폭풍희귀15.33333333%간파의 숨결희귀15.33333333%간파의 장막희귀1.00000000%간파의 비상희귀1.00000000%간파의 삭풍희귀1.00000000%합계100.00000000%1-21.
#     희귀 무기 외형 소환 - 단검이름등급소환 <em>확률</em>어둠의 돌풍희귀17.00000000%어둠의 안개희귀17.00000000%어둠의 바람희귀17.00000000%어둠의 증폭희귀15.33333333%어둠의 폭풍희귀15.33333333%어둠의 숨결희귀15.33333333%어둠의 장막희귀1.00000000%어둠의 비상희귀1.00000000%어둠의 삭풍희귀1.00000000%합계100.00000000%1-22.
# 38216: 5.5055420000: 무기 외형 교체 확률이 궁금해요.
#     무기 외형 교체 <em>확률을</em> 안내해 드립니다.
#     무기 외형 교체무기 외형 교체 : 영웅 - 양손검이름등급소환 <em>확률</em>일격의 화염영웅9.00000000%일격의 불씨영웅9.00000000%일격의 처형영웅9.00000000%일격의 분노영웅9.00000000%일격의 폭발영웅9.00000000%일격의 격돌영웅9.00000000%일격의 학살영웅7.60000000%일격의 응징영웅7.60000000%일격의 투지영웅7.60000000%일격의 불길영웅7.60000000%일격의 맹진영웅7.60000000%일격의 불꽃영웅1.60000000%일격의 포효영웅1.60000000%일격의 홍염영웅1.60000000%일격의 정열영웅1.60000000%일격의 용기영웅1.60000000%합계100.00000000%무기 외형 교체 : 영웅 - 창이름등급소환 <em>확률</em>쇄도의 화염영웅9.00000000%쇄도의 불씨영웅9.00000000%쇄도의 처형영웅9.00000000%쇄도의 분노영웅9.00000000%쇄도의 폭발영웅9.00000000%쇄도의 격돌영웅9.00000000%쇄도의 학살영웅7.60000000%쇄도의 응징영웅7.60000000%
#
# 쇄도의 투지영웅7.60000000%쇄도의 불길영웅7.60000000%쇄도의 맹진영웅7.60000000%쇄도의 불꽃영웅1.60000000%쇄도의 포효영웅1.60000000%쇄도의 홍염영웅1.60000000%쇄도의 정열영웅1.60000000%쇄도의 용기영웅1.60000000%합계100.00000000%무기 외형 교체 : 영웅 - 한손검이름등급소환 <em>확률</em>불굴의 화염영웅9.00000000%불굴의 불씨영웅9.00000000%불굴의 처형영웅9.00000000%불굴의 분노영웅9.00000000%불굴의 폭발영웅9.00000000%불굴의 격돌영웅9.00000000%불굴의 학살영웅7.60000000%불굴의 응징영웅7.60000000%불굴의 투지영웅7.60000000%불굴의 불길영웅7.60000000%불굴의 맹진영웅7.60000000%불굴의 불꽃영웅1.60000000%불굴의 포효영웅1.60000000%불굴의 홍염영웅1.60000000%불굴의 정열영웅1.60000000%
#     불굴의 용기영웅1.60000000%합계100.00000000%무기 외형 교체 : 영웅 - 쌍검이름등급소환 <em>확률</em>고통의 화염영웅9.00000000%고통의 불씨영웅9.00000000%고통의 처형영웅9.00000000%고통의 분노영웅9.00000000%고통의 폭발영웅9.00000000%고통의 격돌영웅9.00000000%고통의 학살영웅7.60000000%고통의 응징영웅7.60000000%고통의 투지영웅7.60000000%고통의 불길영웅7.60000000%고통의 맹진영웅7.60000000%고통의 불꽃영웅1.60000000%고통의 포효영웅1.60000000%고통의 홍염영웅1.60000000%고통의 정열영웅1.60000000%고통의 용기영웅1.60000000%합계100.00000000%무기 외형 교체 : 영웅 - 활이름등급소환 <em>확률</em>간파의 화염영웅9.00000000%간파의 불씨영웅9.00000000%간파의 처형영웅9.00000000%간파의 분노영웅9.00000000%간파의 폭발영웅9.00000000%간파의 격돌영웅9.00000000%간파의 학살영웅7.60000000%간파의 응징영웅7.60000000%간파의 투지영웅7.60000000%간파의 불길영웅7.60000000%간파의 맹진영웅7.60000000%간파의 불꽃영웅1.60000000%간파의 포효영웅1.60000000%간파의 홍염영웅1.60000000%간파의 정열영웅1.60000000%간파의 용기영웅1.60000000%합계100.00000000%무기 외형 교체 : 영웅 - 단검이름등급소환 <em>확률</em>어둠의 화염영웅9.00000000%어둠의 불씨영웅9.00000000%어둠의 처형영웅9.00000000%어둠의 분노영웅9.00000000%어둠의 폭발영웅9.00000000%어둠의 격돌영웅9.00000000%어둠의 학살영웅7.60000000%어둠의 응징영웅7.60000000%어둠의 투지영웅7.60000000%어둠의 불길영웅7.60000000%어둠의 맹진영웅7.60000000%어둠의 불꽃영웅1.60000000%어둠의 포효영웅1.60000000%어둠의
#     <em>확률</em>고귀한 지식의 희망전설10.25000000%고귀한 지식의 찬양전설10.25000000%고귀한 지식의 탄복전설10.25000000%고귀한 지식의 광채전설10.25000000%고귀한 지식의 찬미전설7.60000000%고귀한 지식의 권능전설7.60000000%고귀한 지식의 영광전설7.60000000%고귀한 지식의 영예전설7.60000000%고귀한 지식의 광명전설7.60000000%고귀한 지식의 찬가전설4.20000000%고귀한 지식의 축복전설4.20000000%고귀한 지식의 섬광전설4.20000000%고귀한 지식의 휘광전설4.20000000%고귀한 지식의 칭송전설4.20000000%합계100.00000000%무기 외형 교체 : 전설 - 마법봉이름등급소환 <em>확률</em>자애로운 은총의 희망전설10.25000000%자애로운 은총의 찬양전설10.25000000%자애로운 은총의 탄복전설10.25000000%자애로운 은총의 광채전설10.25000000%자애로운 은총의 찬미전설7.60000000%자애로운 은총의 권능전설7.60000000%자애로운 은총의 영광전설7.60000000%자애로운 은총의 영예전설7.60000000%자애로운 은총의 광명전설7.60000000%자애로운 은총의 찬가전설4.20000000%자애로운 은총의 축복전설4.20000000%자애로운 은총의 섬광전설4.20000000%자애로운 은총의 휘광전설4.20000000%자애로운 은총의 칭송전설4.20000000%합계100.00000000%무기 외형 교체 : 신화 - 양손검이름등급소환 <em>확률</em>무너진 세계의 정의신화25.00000000%고결한 긍지의 정의신화25.00000000%폐허에 움트는 정의신화25.00000000%끝없이 휘도는 정의신화25.00000000%합계100.00000000%무기 외형 교체 : 신화 - 창이름등급소환 <em>확률</em>경계를 넘어선 전진신화25.00000000%지평을 초월한 전진신화25.00000000%결의를 관철한 전진신화25.00000000%굳건히 내딛는 전진신화25.00000000%합계100.00000000%
#     무기 외형 교체 : 신화 - 한손검이름등급소환 <em>확률</em>꺾이지 않는 의지신화25.00000000%최후에 빛나는 의지신화25.00000000%어둠을 사르는 의지신화25.00000000%희망을 밝히는 의지신화25.00000000%합계100.00000000%무기 외형 교체 : 신화 - 쌍검이름등급소환 <em>확률</em>멈출 수 없는 공포신화25.00000000%영구히 서리는 공포신화25.00000000%무한히 스미는 공포신화25.00000000%선연히 감도는 공포신화25.00000000%합계100.00000000%무기 외형 교체 : 신화 - 활이름등급소환 <em>확률</em>세상을 탐한 습격신화25.00000000%심연을 딛는 습격신화25.00000000%칠흑을 가르는 습격신화25.00000000%환영에 침범한 습격신화25.00000000%합계100.00000000%무기 외형 교체 : 신화 - 단검이름등급소환 <em>확률</em>죽음에 잠식된 집착신화25.00000000%비틀린 갈망의 집착신화25.00000000%참람한 악몽의 집착신화25.00000000%거짓된 공허의 집착신화25.00000000%합계100.00000000%무기 외형 교체 : 신화 - 지팡이이름등급소환 <em>확률</em>깨지지 않는 섭리신화25.00000000%종언에 이르는 섭리신화25.00000000%근원에 흐르는 섭리신화25.00000000%파멸로 이끄는 섭리신화25.00000000%합계100.00000000%무기 외형 교체 : 신화 - 마법봉이름등급소환 <em>확률</em>영면을 위한 강림신화25.00000000%구원에 닿는 강림신화25.00000000%맹약에 의한 강림신화25.00000000%숭고한 심판의 강림신화25.00000000%합계100.00000000%
# 38205: 4.8297615000: 탈것 합성 확률이 궁금해요.
#     탈것 합성 <em>확률을</em> 안내해 드립니다.
#     탈것 합성탈것 합성 : 일반이름등급소환 <em>확률</em>떠돌이 가시 늑대일반3.20833333%떠돌이 흑곰일반3.20833333%떠돌이 갈기 늑대일반3.20833333%떠돌이 갈색마일반3.20833333%떠돌이 백곰일반3.20833333%떠돌이 해골탈 물소일반3.20833333%떠돌이 가시 표범일반3.20833333%떠돌이 당나귀일반3.20833333%떠돌이 백마일반3.20833333%떠돌이 흑마일반3.20833333%떠돌이 숲곰일반3.20833333%떠돌이 노새일반3.20833333%야생 당나귀일반3.50000000%떠돌이 늑대개일반3.50000000%하얀 깃털 말일반3.50000000%사나운 말일반3.50000000%사나운 해골탈 물소일반3.50000000%사나운 표범일반3.50000000%사나운 당나귀일반3.50000000%떠돌이 갈색곰일반3.50000000%사나운 늑대개일반3.50000000%길들인 가시 늑대고급1.35000000%길들인 흑곰고급1.35000000%길들인 갈기 늑대고급1.35000000%길들인 흑갈기마고급1.35000000%길들인 백곰고급1.35000000%길들인 해골탈 물소고급1.35000000%길들인 가시 표범고급1.35000000%길들인 당나귀고급1.35000000%길들인 백갈기마고급1.35000000%길들인 흑마고급1.35000000%길들인 숲곰고급1.50000000%상인의 당나귀고급1.50000000%짐꾼의 당나귀고급1.50000000%훈련된 흑마고급1.50000000%훈련된 말고급1.50000000%훈련된 갈색곰고급1.50000000%훈련된 늑대개고급1.87500000%훈련된 해골탈 물소고급1.87500000%훈련된 표범고급1.87500000%훈련된 당나귀고급1.87500000%합계100.00000000%탈것 합성 : 고급이름등급소환 <em>확률</em>길들인 가시 늑대고급3.55500000%길들인 흑곰고급3.55500000%길들인 갈기 늑대고급3.55500000%길들인 흑갈기마고급3.55500000%길들인 백곰고급3.55500000%길들인 해골탈 물소고급3.55500000%
#     당나귀고급3.55500000%길들인 백갈기마고급3.55500000%길들인 흑마고급3.55500000%길들인 숲곰고급3.95000000%상인의 당나귀고급3.95000000%짐꾼의 당나귀고급3.95000000%훈련된 흑마고급3.95000000%훈련된 말고급3.95000000%훈련된 갈색곰고급3.95000000%훈련된 늑대개고급4.93750000%훈련된 해골탈 물소고급4.93750000%훈련된 표범고급4.93750000%훈련된 당나귀고급4.93750000%질주의 가시 늑대희귀1.05000000%질주의 흑곰희귀1.05000000%질주의 갈기 늑대희귀1.05000000%질주의 흑마희귀1.05000000%질주의 백곰희귀1.05000000%질주의 전투 물소희귀1.05000000%질주의 가시 표범희귀1.05000000%질주의 당나귀희귀1.05000000%질주의 갑주 백마희귀0.69300000%질주의 왕궁 백마희귀0.69300000%질주의 갑주 흑마희귀0.69300000%질주의 왕궁 흑마희귀0.69300000%질주의 숲곰희귀0.69300000%질주의 갑주곰희귀0.69300000%탐험가의 당나귀희귀0.69300000%모험가의 당나귀희귀0.69300000%질주의 고원 알파카희귀0.69300000%질주의 백사슴희귀0.69300000%질주의 갑주 나귀희귀0.72000000%질주의 갑주 노새희귀0.72000000%질주의 갑주 늑대희귀0.72000000%질주의 전투 늑대희귀0.72000000%질주의 흑멧돼지희귀0.72000000%질주의 숲멧돼지희귀0.72000000%질주의 갑주 돼지희귀0.72000000%질주의 전투 돼지희귀0.07000000%질주의 붉은 사슴희귀0.07000000%질주의 장식 사슴희귀0.07000000%질주의 숲사슴희귀0.07000000%질주의 흑사슴희귀0.07000000%질주의 웰시코기희귀0.07000000%질주의 숲당나귀희귀0.07000000%질주의 얼룩말희귀0.07000000%질주의 얼룩 웰시코기희귀0.07000000%합계100.00000000%탈것 합성 : 희귀이름등급소환 <em>확률</em>질주의
#     흑마희귀2.70600000%질주의 왕궁 흑마희귀2.70600000%질주의 숲곰희귀2.70600000%질주의 갑주곰희귀2.70600000%탐험가의 당나귀희귀2.70600000%모험가의 당나귀희귀2.70600000%질주의 고원 알파카희귀2.70600000%질주의 백사슴희귀2.70600000%질주의 갑주 나귀희귀2.81142857%질주의 갑주 노새희귀2.81142857%질주의 갑주 늑대희귀2.81142857%질주의 전투 늑대희귀2.81142857%질주의 흑멧돼지희귀2.81142857%질주의 숲멧돼지희귀2.81142857%질주의 갑주 돼지희귀2.81142857%질주의 전투 돼지희귀0.27333333%질주의 붉은 사슴희귀0.27333333%질주의 장식 사슴희귀0.27333333%질주의 숲사슴희귀0.27333333%질주의 흑사슴희귀0.27333333%질주의 웰시코기희귀0.27333333%질주의 숲당나귀희귀0.27333333%질주의 얼룩말희귀0.27333333%질주의 얼룩 웰시코기희귀0.27333333%여행자의 당나귀영웅2.40000000%방랑상인의 흑곰영웅2.40000000%명예의 백마영웅2.40000000%명예의 전투 멧돼지영웅1.08000000%명예의 흑마영웅1.08000000%여행자의 해골탈 물소영웅1.08000000%명예의 레서판다영웅1.08000000%여행자의 고원 알파카영웅1.08000000%명예의 전투 물소영웅0.49500000%방랑상인의 당나귀영웅0.49500000%명예의 가시 늑대영웅0.49500000%교역상인의 낙타영웅0.49500000%여행자의 알파카영웅0.49500000%명예의 순록영웅0.49500000%명예의 숲당나귀영웅0.49500000%명예의 얼룩말영웅0.49500000%명예의 당나귀영웅0.24000000%명예의 멧돼지영웅0.24000000%명예의 큰뿔 사슴영웅0.24000000%명예의 큰뿔양영웅0.24000000%우체부 웰시코기영웅0.24000000%우체부 얼룩 웰시코기영웅0.24000000%합계100.00000000%탈것 합성 : 영웅이름등급소환 <em>확률</em>여행자의
#     당나귀영웅11.20000000%방랑상인의 흑곰영웅11.20000000%명예의 백마영웅11.20000000%명예의 전투 멧돼지영웅5.04000000%명예의 흑마영웅5.04000000%여행자의 해골탈 물소영웅5.04000000%명예의 레서판다영웅5.04000000%여행자의 고원 알파카영웅5.04000000%명예의 전투 물소영웅2.31000000%방랑상인의 당나귀영웅2.31000000%명예의 가시 늑대영웅2.31000000%교역상인의 낙타영웅2.31000000%여행자의 알파카영웅2.31000000%명예의 순록영웅2.31000000%명예의 숲당나귀영웅2.31000000%명예의 얼룩말영웅2.31000000%명예의 당나귀영웅1.12000000%명예의 멧돼지영웅1.12000000%명예의 큰뿔 사슴영웅1.12000000%명예의 큰뿔양영웅1.12000000%우체부 웰시코기영웅1.12000000%우체부 얼룩 웰시코기영웅1.12000000%잔지바르의 표범전설3.28000000%백곰 기사전설3.28000000%툰드라의 전투 늑대전설1.21600000%리처드 1세의 흑마전설1.21600000%불곰 기사전설1.21600000%아라비아의 귀족 낙타전설1.21600000%안데스의 알파카전설1.21600000%툰드라의 늑대전설0.56000000%필리프 2세의 백마전설0.56000000%자이언트 엘크전설0.56000000%알폰소 1세의 아이벡스전설0.56000000%개선행진 웰시코기전설0.56000000%군악대장 레서판다전설0.56000000%합계100.00000000%탈것 합성 : 전설이름등급소환 <em>확률</em>잔지바르의 표범전설17.42500000%백곰 기사전설17.42500000%툰드라의 전투 늑대전설6.46000000%리처드 1세의 흑마전설6.46000000%불곰 기사전설6.46000000%아라비아의 귀족 낙타전설6.46000000%안데스의 알파카전설6.46000000%툰드라의 늑대전설2.97500000%필리프 2세의 백마전설2.97500000%자이언트 엘크전설2.97500000%알폰소 1세의

# %%
azsch_text_query_highlight("마력확율")
# Out:
# Search Results:
# 38233: 5.6241016000: 마력 주입 확률이 궁금해요.
#     <em>마력</em> 주입 확률을 안내해 드립니다.
#     <em>마력</em> 주입<em>마력</em> 주입 I구분능력치수치확률1번 능력치PVE 추가 피해315.00%PVE 추가 피해210.00%PVE 추가 피해110.00%생명력 물약 회복량1015.00%생명력 물약 회복량85.00%생명력 물약 회복량65.00%생명력 물약 회복량45.00%생명력 물약 회복량24.50%생명력 물약 회복량10.50%생명력 회복량515.00%생명력 회복량43.75%생명력 회복량33.75%생명력 회복량23.75%생명력 회복량13.75%2번 능력치PVE 명중215.00%PVE 명중120.00%최대 생명력10015.00%최대 생명력872.14%최대 생명력742.14%최대 생명력612.14%최대 생명력482.14%최대 생명력352.14%최대 생명력222.15%최대 생명력102.15%생명력 물약 회복률50015.00%생명력 물약 회복률4005.00%생명력 물약 회복률3005.00%생명력 물약 회복률2005.00%생명력 물약 회복률1005.00%3번 능력치PVE 치명타315.00%PVE 치명타210.00%PVE 치명타110.00%최대 정신력6015.00%최대 정신력532.14%최대 정신력462.14%최대 정신력392.14%최대 정신력322.14%최대 정신력252.14%최대 정신력182.15%최대 정신력102.15%최대 무게5,00015.00%최대 무게4,0005.00%최대 무게3,0005.00%최대 무게2,0005.00%최대 무게1,0005.00%추가 능력치방어2100.00%<em>마력</em> 주입 II구분능력치수치확률1번 능력치기술 피해45.00%기술 피해35.00%기술 피해25.00%기술 피해15.00%정신력 회복량710.00%정신력 회복량63.33%정신력 회복량53.33%정신력 회복량43.33%정신력 회복량33.33%정신력 회복량23.34%정신력 회복량13.34%최대 정신력7015.00%최대 정신력615.00%최대 정신력525.00%최대 정신력435.00%최대 정신력345.00%최대 정신력255.00%최대 정신력165.00%최대 정신력105.00%2번 능력치방어25.00%방어115.00%생명력
#     물약 회복량1010.00%생명력 물약 회복량83.50%생명력 물약 회복량63.50%생명력 물약 회복량43.50%생명력 물약 회복량23.50%생명력 물약 회복량11.00%생명력 물약 회복률50010.00%생명력 물약 회복률4003.75%생명력 물약 회복률3003.75%생명력 물약 회복률2003.75%생명력 물약 회복률1003.75%최대 무게5,00015.00%최대 무게4,0003.75%최대 무게3,0003.75%최대 무게2,0003.75%최대 무게1,0003.75%3번 능력치치명타35.00%치명타27.50%치명타17.50%이중 피해35.00%이중 피해27.50%이중 피해17.50%치명타 저항315.00%치명타 저항27.50%치명타 저항17.50%이중 피해 저항315.00%이중 피해 저항27.50%이중 피해 저항17.50%추가 능력치명중2100.00%<em>마력</em> 주입 III구분능력치수치확률1번 능력치체력25.00%체력110.00%정신25.00%정신110.00%인내25.00%인내110.00%생명력 물약 회복량1510.00%생명력 물약 회복량141.78%생명력 물약 회복량131.78%생명력 물약 회복량121.78%생명력 물약 회복량111.78%생명력 물약 회복량101.78%생명력 물약 회복량91.78%생명력 물약 회복량81.79%생명력 물약 회복량71.79%생명력 물약 회복량61.79%생명력 물약 회복량51.79%생명력 물약 회복량41.79%생명력 물약 회복량31.79%생명력 물약 회복량21.79%생명력 물약 회복량11.79%생명력 물약 회복률80010.00%생명력 물약 회복률7001.40%생명력 물약 회복률6001.40%생명력 물약 회복률5001.40%생명력 물약 회복률4001.40%생명력 물약 회복률3001.40%생명력 물약 회복률2001.50%생명력 물약 회복률1001.50%2번 능력치치명타54.00%치명타42.75%치명타32.75%치명타22.75%치명타12.75%이중 피해54.00%이중 피해42.75%이중 피해32.75%이중 피해22.75%이중 피해12.75%최대 생명력20010.00%
#     최대 생명력1811.00%최대 생명력1621.00%최대 생명력1431.00%최대 생명력1241.00%최대 생명력1051.00%최대 생명력861.00%최대 생명력671.00%최대 생명력481.00%최대 생명력291.00%최대 생명력101.00%최대 정신력12010.00%최대 정신력1091.00%최대 정신력981.00%최대 정신력871.00%최대 정신력761.00%최대 정신력651.00%최대 정신력541.00%최대 정신력431.00%최대 정신력321.00%최대 정신력211.00%최대 정신력101.00%최대 무게8,00010.00%최대 무게7,0002.85%최대 무게6,0002.85%최대 무게5,0002.85%최대 무게4,0002.85%최대 무게3,0002.85%최대 무게2,0002.85%최대 무게1,0002.90%3번 능력치무기 피해154.00%무기 피해132.28%무기 피해112.28%무기 피해92.28%무기 피해72.28%무기 피해52.28%무기 피해32.30%무기 피해12.30%발동 효과 고정 피해 감소104.00%발동 효과 고정 피해 감소84.00%발동 효과 고정 피해 감소64.00%발동 효과 고정 피해 감소44.00%발동 효과 고정 피해 감소24.00%근거리 회피25.00%근거리 회피115.00%원거리 회피25.00%원거리 회피115.00%마법 회피25.00%마법 회피115.00%추가 능력치피해 감소3100.00%<em>마력</em> 주입 IV구분능력치수치확률1번 능력치힘23.00%힘112.00%민첩23.00%민첩112.00%지능23.00%지능112.00%생명력 회복량310.00%생명력 회복량210.00%생명력 회복량110.00%정신력 회복량210.00%정신력 회복량115.00%2번 능력치일반 공격 추가 피해65.00%일반 공격 추가 피해52.00%일반 공격 추가 피해42.00%일반 공격 추가 피해32.00%일반 공격 추가 피해22.00%일반 공격 추가 피해12.00%기술 피해65.00%기술 피해52.00%기술 피해42.00%기술 피해32.00%기술 피해22.00%기술 피해12.00%
#     원거리 회피28.50%원거리 회피18.50%마법 회피33.00%마법 회피28.50%마법 회피18.50%기술 방어35.00%기술 방어210.00%기술 방어110.00%추가 능력치피해 감소 무시10100.00%<em>마력</em> 주입2 VI구분능력치수치확률1번 능력치피해 감소1013.00%피해 감소91.89%피해 감소81.89%피해 감소71.89%피해 감소61.89%피해 감소51.89%피해 감소41.89%피해 감소31.89%피해 감소21.89%피해 감소11.88%근거리 피해 감소53.00%근거리 피해 감소43.00%근거리 피해 감소33.00%근거리 피해 감소23.00%근거리 피해 감소13.00%원거리 피해 감소53.00%원거리 피해 감소43.00%원거리 피해 감소33.00%원거리 피해 감소23.00%원거리 피해 감소13.00%마법 피해 감소53.00%마법 피해 감소43.00%마법 피해 감소33.00%마법 피해 감소23.00%마법 피해 감소13.00%기술 피해 감소83.00%기술 피해 감소73.14%기술 피해 감소63.14%기술 피해 감소53.14%기술 피해 감소43.14%기술 피해 감소33.14%기술 피해 감소23.14%기술 피해 감소13.16%2번 능력치체력32.00%체력26.50%체력16.50%정신32.00%정신26.50%정신16.50%인내32.00%인내26.50%인내16.50%최대 생명력2504.50%최대 생명력2005.11%최대 생명력1505.13%최대 생명력1005.13%최대 생명력505.13%최대 정신력1504.50%최대 정신력1206.36%최대 정신력906.38%최대 정신력606.38%최대 정신력306.38%3번 능력치명중40.50%명중34.83%명중24.83%명중14.84%근거리 명중21.00%근거리 명중119.00%원거리 명중21.00%원거리 명중119.00%마법 명중21.00%마법 명중119.00%기술 명중21.50%기술 명중123.50%추가 능력치범위 피해 감소20100.00%<em>마력</em> 주입2 VII구분능력치수치확률1번 능력치기술 방어108.00%기술 방어92.44%
# 38234: 3.5298173000: 아이템 상자의 확률이 궁금해요.
#     10.80%+6 밤까마귀 깃털 브로치 상자(귀속)15.60%+5 밤까마귀 깃털 브로치 상자(귀속)18.00%+4 밤까마귀 깃털 브로치 상자(귀속)120.00%+3 밤까마귀 깃털 브로치 상자(귀속)165.00%합계100.00% 클레멘스의 재료 상자이름수량확률모리온(귀속)13.00%상급 전직의 증표(귀속)10.05%얼어붙은 눈물(귀속)10.02%상급 단련의 비전서(귀속)10.01%상급 도약의 비전서(귀속)10.01%상급 총명의 비전서(귀속)10.01%상급 번영의 비전서(귀속)10.01%지혜의 원천(귀속)10.01%창공의 조각(귀속)10.01%대장장이의 철주괴(귀속)11.60%세공사의 수정(귀속)11.60%무두장이의 가죽(귀속)11.60%무두장이의 모피(귀속)11.60%목수의 목재(귀속)11.60%고대 파피루스(귀속)12.50%단련의 비전서(귀속)10.75%도약의 비전서(귀속)10.75%총명의 비전서(귀속)10.75%번영의 비전서(귀속)10.75%성장의 원천(귀속)12.87%철주괴(귀속)14.00%수정 결정(귀속)14.00%부드러운 가죽(귀속)14.00%천연 모피(귀속)14.00%목재(귀속)14.00%초정밀 비행 부품(귀속)11.50%월장석(귀속)19.00%혼합 시약(귀속)19.00%철광석(귀속)17.20%수정 광물(귀속)17.20%거친 가죽(귀속)17.20%털뭉치(귀속)17.20%통나무(귀속)17.20%낡은 비행 부품(귀속)15.00%합계100.00%찬란한 장신구 강화 주문서 상자이름수량확률광휘의 장신구 강화 주문서(귀속)10.75%장신구 강화 주문서(귀속)199.25%합계100.00%찬란한 무기 세공석 상자이름수량확률광휘의 무기 세공석(귀속)10.75%무기 세공석(귀속)199.25%합계100.00%찬란한 방어구 세공석 상자이름수량확률광휘의 방어구 세공석(귀속)10.75%방어구 세공석(귀속)199.25%합계100.00%찬란한 장신구 세공석 상자이름수량확률광휘의 장신구 세공석(귀속)10.75%장신구 세공석(귀속)199.25%합계100.00%6월 15일(목) 추가 확률형 상품<em>마력</em>
#     룬 결정 II 랜덤 상자이름수량확률<em>마력</em> 룬 결정 II(귀속)548.50%<em>마력</em> 룬 결정 II(귀속)730.00%<em>마력</em> 룬 결정 II(귀속)1015.00%<em>마력</em> 룬 결정 II(귀속)203.00%<em>마력</em> 룬 결정 II(귀속)302.00%<em>마력</em> 룬 결정 II(귀속)401.00%<em>마력</em> 룬 결정 II(귀속)500.50%합계100.00%6월 29일(목) 추가 확률형 상품검은 날개 보급품이름수량확률돌격의 영약(귀속)209.00%필승의 영약(귀속)109.00%음식 바구니(귀속)59.00%파수의 영약(귀속)59.00%영약 선택 상자(귀속)39.00%월광 보호 부적(귀속)39.00%태양 전투 부적(귀속)39.00%무기 강화 주문서(귀속)26.15%방어구 강화 주문서(귀속)26.15%장신구 강화 주문서(귀속)26.15%무기 세공석(귀속)26.15%방어구 세공석(귀속)26.15%장신구 세공석(귀속)26.15%모리온(귀속)1000.10%합계100.00%8월 3일(목) 추가 확률형 상품100일 기념 클레멘스의 재료 상자이름수량확률얼어붙은 눈물(귀속)122.0%지혜의 원천(귀속)11.0%상급 단련의 비전서(귀속)10.5%상급 도약의 비전서(귀속)10.5%상급 총명의 비전서(귀속)10.5%상급 번영의 비전서(귀속)10.5%단련의 비전서(귀속)111.0%도약의 비전서(귀속)111.0%총명의 비전서(귀속)111.0%번영의 비전서(귀속)111.0%광휘의 무기 강화 주문서(귀속)11.0%광휘의 방어구 강화 주문서(귀속)11.0%광휘의 장신구 강화 주문서(귀속)11.0%초정밀 비행 부품(귀속)128.0%합계100.00%8월 10일(목) 추가 확률형 상품100일 기념 클레멘스의 재료 상자 II이름수량확률대장장이의 철주괴(귀속)52.5%무두장이의 가죽(귀속)52.5%무두장이의 모피(귀속)52.5%세공사의 수정(귀속)52.5%철주괴(귀속)255.0%부드러운 가죽(귀속)255.0%천연 모피(귀속)255.0%수정 결정(귀속)255.0%금속 파편(귀속)5025.0%골드 상자(귀속)120.0%사금 주머니(귀속)125.0%
# 17: 3.4898458000: 물약을 자동으로 사용하도록 설정했는데 완전하게 회복되지 않아요.
#     나이트크로우에서 물약 자동 사용 설정 기본값은 체력/<em>마력</em> 동일하게 80% 이하일 때 자동 사용되도록 설정되어 있습니다
# 38218: 2.6304386000: 제작 확률이 궁금해요.
#     격류 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 집념 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 집념 III(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 고밀도 <em>마력</em> II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 특이점 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 과부하 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 연소 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 화염 폭발 III(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 신성 번개 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 치유 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 소생 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 구출 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 치유의 주문 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 권능 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 윤회 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 깨우침 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 성화 II(귀속)100.00%0%0.00%100%총명의 제작술노련희귀기술서 부록 - 신성 번개 III(귀속)100.00%0%0.00%100%총명의 제작술숙련고급천연 모피(귀속)95.00%0%5.00%100%총명의 제작술숙련희귀무두장이의 모피(귀속)100.00%0%0.00%100%총명의 제작술숙련희귀총명의 비전서(귀속)95.00%0%5.00%100%총명의 제작술숙련영웅상급 총명의 비전서(귀속)100.00%0%
#     0.00%100%총명의 제작술숙련희귀기술서 - 빙산의 일각 I(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 - 태초의 섬광 I(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 - 축복의 성배 I(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 빙산의 일각 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 태초의 섬광 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 축복의 성배 II(귀속)98.00%0%2.00%100%총명의 제작술숙련영웅기술서 - <em>마력</em> 탄환 I(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 - 탄로 I(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - <em>마력</em> 탄환 II(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 탄로 II(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 - 주문 증폭 I(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 주문 증폭 II(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 동결 II(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 - 빛나는 치유 I(귀속)100.00%0%0.00%ㄹ총명의 제작술숙련영웅기술서 부록 - 빛나는 치유 II(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 세례 II(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 깨어난 영감: 지팡이 II(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 깨어난 영감: 마법봉 II(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 깨어난 영감: 지팡이 III(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 깨어난 영감: 마법봉 III(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서
#     - 철갑의 수호 I(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 철갑의 수호 II(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 철갑의 수호 III(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 영혼 결계 II(귀속)100.00%0%0.00%100%총명의 제작술숙련영웅기술서 부록 - 풍요 II(귀속)100.00%0%0.00%100%총명의 제작술숙련희귀기술서 부록 - 화염 폭발 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 정신력 회복 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - <em>마력</em> 격류 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 집념 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 집념 III(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 고밀도 <em>마력</em> II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 특이점 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 과부하 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 연소 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 화염 폭발 III(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 신성 번개 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 치유 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 소생 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 구출 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 치유의 주문 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 권능 II(귀속)98.00%0%2.00%100%총명의
#     제작술숙련희귀기술서 부록 - 윤회 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 깨우침 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 성화 II(귀속)98.00%0%2.00%100%총명의 제작술숙련희귀기술서 부록 - 신성 번개 III(귀속)98.00%0%2.00%100%총명의 제작술전문희귀무두장이의 모피(귀속)95.00%0%5.00%100%총명의 제작술전문희귀총명의 비전서(귀속)95.00%0%5.00%100%총명의 제작술전문영웅상급 총명의 비전서(귀속)95.00%0%5.00%100%총명의 제작술전문전설최상급 총명의 비전서(귀속)100.00%0%0.00%100%총명의 제작술전문영웅기술서 - 주문 증폭 I(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 부록 - 주문 증폭 II(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 부록 - 동결 II(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 - 빛나는 치유 I(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 부록 - 빛나는 치유 II(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 부록 - 세례 II(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 - <em>마력</em> 탄환 I(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 - 탄로 I(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 부록 - <em>마력</em> 탄환 II(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 부록 - 탄로 II(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 부록 - 깨어난 영감: 지팡이 II(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 부록 - 깨어난 영감: 마법봉 II(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 부록 - 깨어난 영감: 지팡이 III(귀속)99.00%0%1.00%100%총명의 제작술전문영웅기술서 부록 - 깨어난
#     룬 결정 I(귀속)100.00%0%0.00%100%일반 제작없음희귀<em>마력</em> 룬 결정 II(귀속)100.00%0%0.00%100%일반 제작없음영웅<em>마력</em> 룬 결정 III(귀속)100.00%0%0.00%100%일반 제작없음고급<em>마력</em> 별빛 결정 I(귀속)100.00%0%0.00%100%일반 제작없음희귀<em>마력</em> 별빛 결정 II(귀속)100.00%0%0.00%100%일반 제작없음영웅<em>마력</em> 별빛 결정 III(귀속)100.00%0%0.00%100%일반 제작없음영웅<em>마력</em> 서리 결정 I(귀속)100.00%0%0.00%100%일반 제작없음고급가공된 금속 파편(귀속)100.00%0%0.00%100%일반 제작없음영웅금빛 여명 휘장(귀속)10.00%90%0.00%100%일반 제작없음영웅백은 방패 휘장(귀속)10.00%90%0.00%100%일반 제작없음영웅붉은 십자 휘장(귀속)10.00%90%0.00%100%일반 제작없음영웅검은 수리 휘장(귀속)10.00%90%0.00%100%일반 제작없음전설사자왕의 신성 휘장(귀속)100.00%0%0.00%100%일반 제작없음전설황금 흉갑 휘장(귀속)10.00%90%0.00%100%일반 제작없음전설황금 장갑 휘장(귀속)10.00%90%0.00%100%일반 제작없음영웅전직의 서(귀속)100.00%0%0.00%100%일반 제작없음전설상급 전직의 서(귀속)100.00%0%0.00%100%일반 제작없음신화최상급 전직의 서(귀속)100.00%0%0.00%100%일반 제작없음영웅수석 장인의 증명패(귀속)10.00%90%0.00%100%일반 제작없음영웅용병대장의 추천서(귀속)7.00%93%0.00%100%일반 제작없음전설교황의 인가(귀속)25.00%75%0.00%100%일반 제작없음전설신왕의 승인(귀속)20.00%80%0.00%100%공통제한 없음일반+6 영롱한 유물(귀속)100.00%0%0.00%100%공통제한 없음일반+7 영롱한 유물(귀속)100.00%0%0.00%100%공통제한 없음일반+8 영롱한 유물(귀속)100.00%0%0.00%100%공통제한 없음일반+9 영롱한 유물
